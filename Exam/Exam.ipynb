# %% [markdown]
# <a href="https://colab.research.google.com/github/visiont3lab/machine_learning/blob/master/Exam/Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Esercizione Supervised Learning Regressione
#
# **Difficoltà: Semplice**
#
# Obbiettivo:
# * Dato un dataset (california_housing, diabetes) si vuole implemetare un algoritmo capace di predirre un risultato futuro.
#
# Guideline:
#   1. Analizzare i dati usando la libreria pandas
#   2. Preprocessare i dati (StandardScaler, MinMaxScaler, PCA)
#   3. Dividere i dati in traning/test set
#   4. Implementare un regressore lineare
#   5. Implementare un regressore polinomiale
#   6. Confrontare i regressori
#   7. Testare e salvare il modello
#
# References:
#   * [Regressione lineare spiegazione](https://colab.research.google.com/github/visiont3lab/machine_learning/blob/master/02-Regressione/02_RegressioneLineare.ipynb)
#   * [Regressione esempio ](https://colab.research.google.com/github/visiont3lab/machine_learning/blob/master/06-RegressioneEsempio/06_RegressioneEsempio.ipynb)
#   * [PCA e regressione](https://colab.research.google.com/github/visiont3lab/machine_learning/blob/master/04-Datasets/04_scikit_learn_Dataset_PCA.ipynb)

# %%
from sklearn.datasets import fetch_california_housing, load_boston
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
# Download dataset 
dataset = fetch_california_housing()
dataset = load_boston()

print(dataset.keys())
print(dataset.DESCR)
# Out:
# ...
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
# ...

# %% [markdown]
# # Esercizio Supervised Learning Classificazione
#
# **Difficoltà: Media**
#
# Obbiettivo:
#   * Dato un dataset (classificazione binaria o multiclass) si vuole implemetare un algoritmo capace di classificare.
#
# Guideline:
#   1. Analizzare i dati usando la libreria pandas e opencv
#   2. Preprocessare i dati (StandardScaler, MinMaxScaler, PCA)
#   3. Dividere i dati in traning/test set
#   4. Implementare un classificatore (Decision Tree, SVM, Random Forest, Logistic Regression). Extra considerare
#   5. Analizzare precision, recall, F1score
#   6. Testare e salvare il modello
#
# Extra:
#   * Generare un dataset custom
#   * Applicare parameters search grid e pipeline
#
# References:
#  * [Binary Classifier](https://colab.research.google.com/github/visiont3lab/machine_learning/blob/master/08-classification/binary_classification.ipynb)
#
#  * [Classification Recap](https://colab.research.google.com/github/visiont3lab/machine_learning/blob/master/11-ClassificationProject/multilabel_classification.ipynb)
#  * [Classificaiton  Example](https://colab.research.google.com/github/visiont3lab/machine_learning/blob/master/13-ClassificationEmotions/clf_teachable_machine/classification_SVM.ipynb)

# %%
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
dataset = load_breast_cancer()   # binary classification

# %%
# Binary classifcaiton mnist
dataset = fetch_openml('mnist_784', version=1)
n_classes = 10
X = dataset["data"]
Y = dataset["target"]
print(dataset.keys())
Y = Y.astype(np.uint8) # convert string target to int
#Y = label_binarize(Y, classes=[*range(n_classes)]) # make categorical
X = np.array(X, dtype="float32")
Y = np.array(Y, dtype="float32")
print("X_train shape: ", X_train.shape)
print("Y_train shape: ", Y_train.shape)
print("X_test shape: ", X_test.shape)
print("Y_test shape: ", Y_test.shape)

# %%
dataset = fetch_olivetti_faces() # multiclass classification

# %% [markdown]
# # Esercizio Unsupervised Learning Clustering
#
# **Difficoltà: Semplice**
#
# Obbiettivo:
#   * Dato un dataset senza label raggruppare i dati in clusters.
#
# Guideline:
#   1. Normalizzare i dati (StandardScaler, MinMaxScaler)
#   2. Applicare Kmeans
#   3. Verificare la scelta dei cluster usando Elbow Method e Silhouette
#   4. Applicare DBSCAN
#   5. Comparare i risultati
#
# Reference
# * [Clustering Theory and Execise](https://colab.research.google.com/github/visiont3lab/machine_learning/blob/master/15-Clustering/K_Means.ipynb)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # for plot styling
import numpy as np
from sklearn.datasets.samples_generator import make_blobs
from sklearn.metrics import pairwise_distances_argmin, pairwise_distances
from sklearn.datasets import load_sample_image
from sklearn.cluster import KMeans, DBSCAN

# Geta data
X, y_true = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)
plt.scatter(X[:, 0], X[:, 1], s=50);

# %%
from google.colab import files
from io import BytesIO
from PIL import Image
uploaded = files.upload()

# %%
name = list(uploaded.keys())
print(name)
im = np.array(Image.open(BytesIO(uploaded[name[0]])))

# %%
im = load_sample_image('flower.jpg') # china.jpg
im =  np.array(im, dtype=np.float64) / 255
plt.imshow(im)
