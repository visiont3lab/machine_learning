# %%
print('hi FAV')
# Out:
# hi FAV

# %%
import xxxxxx
import xxxxxx
import xxxxxx
# %matplotlib xxxxxx
from sklearn xxxxxx

# %%
#df = pd.read_csv("Iris.csv")
#X = df.iloc[:, 1:5]
#y = df.iloc[:, 5]
#or 
iris = datasets.load_xxxxxx()
df=pd.DataFrame(iris['xxxxxx'],columns=['Petal Length','Petal Width','Sepal Length','Sepal Width'])
df['Species']=iris['xxxxxx']
df['Species']=df['Species'].apply(lambda x: iris['target_names'][x])

# %%
df.xxxxxx()
# Out:
#    Petal Length  Petal Width  Sepal Length  Sepal Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.xxxxxx()
# Out:
#        Petal Length  Petal Width  Sepal Length  Sepal Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Samples from each species
df["xxxxxx"].value_counts()
# Out:
# versicolor    50
# setosa        50
# virginica     50
# Name: Species, dtype: int64

# %%
X = iris.xxxxxx
y = iris.xxxxxx

# %%
# 30% test set
from sklearn.model_selection import train_test_split
xxxxxx, xxxxxx, xxxxxx, xxxxxx = train_test_split(X, y, test_size=xxxxxx, random_state=667)

# %%
print('There are {} samples in the training set and {} samples in the test set'.format(X_train.shape[0], X_test.shape[0]))
# Out:
# There are 105 samples in the training set and 45 samples in the test set

# %%
#Scaling data
from sklearn.preprocessing import xxxxxx
from sklearn.model_selection import cross_val_score

sc = StandardScaler()
sc.fit(xxxxxx)
X_train_std = sc.transform(xxxxxx)
X_test_std = sc.transform(xxxxxx)

# %%
#Applying Logistic regression
from sklearn.linear_model import xxxxxx

logistic_regression = LogisticRegression()
logistic_regression.fit(xxxxxx,xxxxxx)

print('The accuracy of the Logistic regression classifier on training data is {:.2f}'.format(logistic_regression.score(X_train_std, y_train)))
print('The accuracy of the Logistic regression classifier on test data is {:.2f}'.format(logistic_regression.score(X_test_std, y_test)))

# %%
#Applying Decision Tree
from sklearn import xxxxxx

decision_tree = tree.DecisionTreeClassifier(criterion='gini')
decision_tree.fit(X_train_std, xxxxxx)

print('The accuracy of the Decision Tree classifier on training data is {:.2f}'.format(decision_tree.score(X_train_std, y_train)))
print('The accuracy of the Decision Tree classifier on test data is {:.2f}'.format(decision_tree.score(X_test_std, y_test)))
# Out:
# The accuracy of the Decision Tree classifier on training data is 1.00
# The accuracy of the Decision Tree classifier on test data is 0.98

# %%
#Applying Knn
from sklearn.neighbors import xxxxxx

knn = KNeighborsClassifier(n_neighbors = 7, p = 2)
knn.fit(xxxxxx, y_train)

print('The accuracy of the Knn classifier on training data is {:.2f}'.format(knn.score(X_train_std, y_train)))
print('The accuracy of the Knn classifier on test data is {:.2f}'.format(knn.score(X_test_std, y_test)))
# Out:
# The accuracy of the Knn classifier on training data is 0.95
# The accuracy of the Knn classifier on test data is 0.96

# %%
#Applying Random Forest
from sklearn.ensemble import xxxxxx

random_forest = RandomForestClassifier()
random_forest.fit(xxxxxx, xxxxxx)

print('The accuracy of the Random Forest classifier on training data is {:.2f}'.format(random_forest.score(X_train_std, y_train)))
print('The accuracy of the Random Forest classifier on test data is {:.2f}'.format(random_forest.score(X_test_std, y_test)))
# Out:
# The accuracy of the Random Forest classifier on training data is 1.00
# The accuracy of the Random Forest classifier on test data is 0.98

# %%
#Applying XGBoost
import xgboost as xxxxxx

xgb_clf = xgb.XGBClassifier()
xgb_clf = xgb_clf.fit(xxxxxx, xxxxxx)

print('The accuracy of the XGBoost classifier on training data is {:.2f}'.format(xgb_clf.score(X_train_std, y_train)))
print('The accuracy of the XGBoost classifier on test data is {:.2f}'.format(xgb_clf.score(X_test_std, y_test)))
# Out:
# The accuracy of the XGBoost classifier on training data is 1.00
# The accuracy of the XGBoost classifier on test data is 0.96

# %%
#Applying SVM
from sklearn.svm import xxxxxx

svm = SVC(kernel='rbf', random_state=667, gamma=.10, C=1.0)
svm.fit(xxxxxx, xxxxxx)
print('The accuracy of the SVM classifier on training data is {:.2f}'.format(svm.score(X_train_std, y_train)))
print('The accuracy of the SVM classifier on test data is {:.2f}'.format(svm.score(X_test_std, y_test)))
# Out:
# The accuracy of the SVM classifier on training data is 0.96
# The accuracy of the SVM classifier on test data is 0.96

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,11))
sns.heatmap(xxxxxx(),annot=True)
plt.plot()
# Out:
# []

# %%
sns.pairplot(xxxxxx,xxxxxx, size=3)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.jointplot(x="xxxxxx", y="xxxxxx", data=df, size=5)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:2262: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.jointplot(x="xxxxxx", y="xxxxxx", data=df, size=5)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:2262: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(df, hue="xxxxxx", size=5) \
   .map(plt.scatter, "xxxxxx", "xxxxxx") \
   .add_legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
KS = {'color': ['blue', 'red', 'yellow']}
sns.FacetGrid(df, hue_kws=KS, hue="Species", size=5) \
   .map(plt.scatter, "xxxxxx", "xxxxxx") \
   .add_legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(x="xxxxxx", y="xxxxxx", data=df )

# %%
ax= sns.xxxxxx(x="Species", y="Petal Length", data=xxxxxx)
ax= sns.stripplot(x="Species", y="Petal Length", data=df, jitter=True, edgecolor="gray")

# %%
ax= sns.boxplot(x="Species", y="Petal Length", data=xxxxxx)
ax= sns.xxxxxx(x="Species", y="xxxxxx", data=df, jitter=True, edgecolor="gray")

boxtwo = ax.artists[2]
boxtwo.set_facecolor('red')
boxtwo.set_edgecolor('black')
boxthree=ax.artists[1]
boxthree.set_facecolor('yellow')
boxthree.set_edgecolor('black')

# %%
sns.xxxxxx(x="Species", y="Petal Length", data=df, size=6)

# %%
sns.xxxxxx(x="xxxxxx", y="Petal Length",  palette={"blue","red","yellow"}, data=df, size=6)

# %%
sns.xxxxxx(df, hue="Species", size=5) \
   .map(sns.kdeplot, "Petal Length") \
   .add_legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.jointplot(x="xxxxxx", y="xxxxxx", data=df, size=10,ratio=10, kind='hex',color='green')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:2262: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df.boxplot(by="xxxxxx", figsize=(10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8fade599b0>,
# ...
#       dtype=object)

# %%
from pandas.plotting import andrews_curves
andrews_curves(df, "xxxxxx",colormap='rainbow')

# %%
from pandas.plotting import parallel_coordinates
parallel_coordinates(xxxxxx, "xxxxxx",colormap='cool')

# %%
from pandas.plotting import radviz
radviz(xxxxxx, "xxxxxx",colormap='autumn')
