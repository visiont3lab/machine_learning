# %% [markdown]
# # Classification using SpaCy

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.6/dist-packages (2.1.9)
# Requirement already satisfied: blis<0.3.0,>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.2.4)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.9.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.17.5)
# Requirement already satisfied: thinc<7.1.0,>=7.0.8 in /usr/local/lib/python3.6/dist-packages (from spacy) (7.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.21.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.6.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.2)
# Requirement already satisfied: preshed<2.1.0,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.0.1)
# Requirement already satisfied: srsly<1.1.0,>=0.0.6 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.0.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python3.6/dist-packages (from thinc<7.1.0,>=7.0.8->spacy) (4.28.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2019.11.28)

# %%
# !python -m spacy download en
# Out:
# Requirement already satisfied: en_core_web_sm==2.1.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.1.0/en_core_web_sm-2.1.0.tar.gz#egg=en_core_web_sm==2.1.0 in /usr/local/lib/python3.6/dist-packages (2.1.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: en_core_web_sm==2.1.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.1.0/en_core_web_sm-2.1.0.tar.gz#egg=en_core_web_sm==2.1.0 in /usr/local/lib/python3.6/dist-packages (2.1.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %% [markdown]
# ### Bag of Words - The Simplest Word Embedding Technique

# %% [markdown]
# This is one of the simplest methods of embedding words into numerical vectors. It is not often used in practice due to its oversimplification of language, but often the first embedding technique to be taught in the classroom setting.

# %% [markdown]
# ```
# doc1 = "I am high"
# doc2 = "Yes I am high"
# doc3 = "I am kidding"
#
# ```

# %%
from IPython.display import Image
Image(url= "https://frenzy86.s3.eu-west-2.amazonaws.com/fav/nlp/1.PNG", width=500, height=300)
# Out:
# <img src="https://frenzy86.s3.eu-west-2.amazonaws.com/fav/nlp/1.PNG" width="500" height="300"/>

# %% [markdown]
# ### Bag of Words and Tf-idf
# https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html
#
# tf–idf for “Term Frequency times Inverse Document Frequency

# %%
Image(url= "https://frenzy86.s3.eu-west-2.amazonaws.com/fav/nlp/2.PNG", width=600, height=600)
# Out:
# <img src="https://frenzy86.s3.eu-west-2.amazonaws.com/fav/nlp/2.PNG" width="600" height="600"/>

# %%
Image(url= "https://frenzy86.s3.eu-west-2.amazonaws.com/fav/nlp/3.PNG", width=600, height=200)
# Out:
# <img src="https://frenzy86.s3.eu-west-2.amazonaws.com/fav/nlp/3.PNG" width="600" height="200"/>

# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
text = "Apple, This is first sentence. and Google this is another one. here 3rd one is"

# %%
doc = nlp(text)

# %%
doc
# Out:
# Apple, This is first sentence. and Google this is another one. here 3rd one is

# %%
for token in doc:
    print(token)
# Out:
# Apple
# ,
# This
# is
# first
# sentence
# .
# and
# Google
# this
# is
# another
# one
# .
# here
# 3rd
# one
# is

# %%
sent = nlp.create_pipe('sentencizer')

# %%
nlp.add_pipe(sent, before='parser')

# %%
doc = nlp(text)

# %%
for sent in doc.sents:
    print(sent)
# Out:
# Apple, This is first sentence.
# and Google this is another one.
# here 3rd one is

# %%
from spacy.lang.en.stop_words import STOP_WORDS

# %%
stopwords = list(STOP_WORDS)

# %%
print(stopwords)
# Out:
# ['now', 'four', 'another', 'also', 'both', 'under', 'towards', 'once', 'hereafter', 'when', 'forty', 'back', 'himself', 'thereafter', 'take', 'doing', 'meanwhile', 'three', 'hundred', 'is', 'nothing', 'her', 'many', 'anywhere', 'several', 'together', 'you', "'d", 'still', 'often', '’re', 'somehow', 'ten', 'therein', 'before', 'an', 'third', 'latter', 'amount', 'though', 'using', "'s", 'neither', '’s', 'from', 'be', 'anyhow', 'formerly', 'by', 'above', 'has', 'him', 'on', 'hereby', 'that', 'was', 'wherever', 'always', 'its', 'themselves', "'ll", "'re", '’d', 'keep', 'he', 'it', 'amongst', 'must', 'since', 'we', 'please', 'put', 'twenty', 'yourselves', 'per', 'n‘t', 'any', 'fifty', 'had', 'whatever', 'except', 'same', 'serious', 'nine', 'over', 'so', 'something', 'give', 'our', 'than', 'various', 'whoever', 'besides', 'afterwards', 'again', 'am', 'too', 'your', 'anything', 'n’t', 'twelve', 'a', 'very', 'one', 'show', 'if', 'less', 'as', 'eight', 'due', 'whereupon', 'down', 'hereupon', 'their', 'rather', 'get', 'anyway', 'name', 'else', 'seems', 'bottom', 'whither', 'whom', 'how', 'wherein', 'everyone', 'eleven', 'front', 'done', 'everywhere', 'see', 'well', 'whereafter', 'whether', 'thru', 'mine', 'alone', 'last', 'full', 'thence', "n't", 'first', 'becomes', 'beyond', 'i', 'much', 'onto', 'really', 'nowhere', 'these', 'off', 'while', 'everything', 'or', 'others', 'among', '‘ll', 'there', 'sometimes', 'go', 'perhaps', 'did', 'enough', 'someone', 'where', 'yet', 'say', 'to', 'moreover', 'nobody', 'being', 'not', 'own', 'whereas', 'yours', 'through', 'them', 'whose', 'after', 'yourself', 'but', 'may', '‘s', '’ve', 'upon', 'none', 'regarding', 'seemed', 'those', 'become', 'side', 'never', 'ours', '‘m', 'this', 'until', 'out', 'can', 'five', 'other', 'might', "'ve", 'some', 'seem', 'does', 'ever', 'however', 'six', 'two', 'why', 'myself', 'herself', 'thereupon', 'toward', 'part', 'beside', 'below', 'do', 'more', 'thereby', 'via', 'who', 'already', 'each', 'somewhere', 'next', 'should', 'hence', 'could', 'his', 'empty', 'call', 'whole', 'ourselves', 'mostly', 'are', 'behind', 'of', 'seeming', 'here', 'such', 'what', 'make', 'whenever', 'herein', 'would', 'whereby', 'otherwise', 'throughout', 'my', 'becoming', 'anyone', 'cannot', 'top', 'which', 'for', 'along', 'sixty', 'just', 'made', 'within', 'us', 'beforehand', 'used', 'further', '‘d', 'with', 'hers', 'noone', 'then', "'m", '‘ve', 'move', '’m', 'every', 'became', 'almost', 'up', 'no', 'she', 'been', 'nevertheless', 'in', 'the', 'latterly', 'around', 'either', 'without', 'during', 'about', 're', 'against', 'itself', 'into', 'most', 'nor', 'least', 'elsewhere', 'across', 'few', 'unless', 'fifteen', 'only', 'former', 'even', 'me', '‘re', 'at', 'namely', 'will', 'ca', '’ll', 'all', 'although', 'and', 'because', 'between', 'they', 'therefore', 'thus', 'have', 'quite', 'were', 'indeed', 'sometime', 'whence']

# %%
len(stopwords)
# Out:
# 326

# %%
for token in doc:
    if token.is_stop == False:
        print(token)
# Out:
# Apple
# ,
# sentence
# .
# Google
# .
# 3rd

# %% [markdown]
# ### Lemmatization

# %%
doc = nlp('run runs running runner')

# %%
for lem in doc:
    print(lem.text, lem.lemma_)
# Out:
# run run
# runs run
# running run
# runner runner

# %% [markdown]
# ### POS

# %%
doc = nlp('All is well at your end!')

# %%
for token in doc:
    print(token.text, token.pos_)
# Out:
# All DET
# is VERB
# well ADV
# at ADP
# your DET
# end NOUN
# ! PUNCT

# %%
displacy.render(doc, style = 'dep', jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="65fdf6b6b1164e0189c96d92e30ed0aa-0" class="displacy" width="1100" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">All</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">well</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">your</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">end!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-65fdf6b6b1164e0189c96d92e30ed0aa-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-65fdf6b6b1164e0189c96d92e30ed0aa-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-65fdf6b6b1164e0189c96d92e30ed0aa-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-65fdf6b6b1164e0189c96d92e30ed0aa-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M395.0,179.0 L403.0,167.0 387.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-65fdf6b6b1164e0189c96d92e30ed0aa-0-2" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-65fdf6b6b1164e0189c96d92e30ed0aa-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,179.0 L583.0,167.0 567.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-65fdf6b6b1164e0189c96d92e30ed0aa-0-3" stroke-width="2px" d="M770,177.0 C770,89.5 920.0,89.5 920.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-65fdf6b6b1164e0189c96d92e30ed0aa-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,179.0 L762,167.0 778,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-65fdf6b6b1164e0189c96d92e30ed0aa-0-4" stroke-width="2px" d="M595,177.0 C595,2.0 925.0,2.0 925.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-65fdf6b6b1164e0189c96d92e30ed0aa-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M925.0,179.0 L933.0,167.0 917.0,167.0" fill="currentColor"/>
# </g>
# </svg>

# %% [markdown]
# ### Entity Detection

# %%
doc = nlp("New York City on Tuesday declared a public health emergency and ordered mandatory measles vaccinations amid an outbreak, becoming the latest national flash point over refusals to inoculate against dangerous diseases. At least 285 people have contracted measles in the city since September, mostly in Brooklyn’s Williamsburg neighborhood. The order covers four Zip codes there, Mayor Bill de Blasio (D) said Tuesday. The mandate orders all unvaccinated people in the area, including a concentration of Orthodox Jews, to receive inoculations, including for children as young as 6 months old. Anyone who resists could be fined up to $1,000.")

# %%
doc
# Out:
# New York City on Tuesday declared a public health emergency and ordered mandatory measles vaccinations amid an outbreak, becoming the latest national flash point over refusals to inoculate against dangerous diseases. At least 285 people have contracted measles in the city since September, mostly in Brooklyn’s Williamsburg neighborhood. The order covers four Zip codes there, Mayor Bill de Blasio (D) said Tuesday. The mandate orders all unvaccinated people in the area, including a concentration of Orthodox Jews, to receive inoculations, including for children as young as 6 months old. Anyone who resists could be fined up to $1,000.

# %%
displacy.render(doc, style = 'ent',jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     New York City
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  declared a public health emergency and ordered mandatory measles vaccinations amid an outbreak, becoming the latest national flash point over refusals to inoculate against dangerous diseases.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     At least 285
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  people have contracted measles in the city since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     September
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , mostly in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Brooklyn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ’s
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Williamsburg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  neighborhood. The order covers
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  Zip codes there, Mayor
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Bill de Blasio
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (D) said
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The mandate orders all unvaccinated people in the area, including a concentration of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Orthodox Jews
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# , to receive inoculations, including for children as young as
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     6 months old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Anyone who resists could be fined
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     up to $1,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# .</div>

# %% [markdown]
# ### Text Classification

# %%
import ####################################

# %%
from sklearn ####################################
from sklearn ####################################
from sklearn ####################################
from sklearn ####################################

# %%
data_yelp = pd.read_csv('https://frenzy86.s3.eu-west-2.amazonaws.com/fav/nlp/yelp_labelled.txt', ###, #####)

# %%
data_yelp.head()
# Out:
#                                                    0  1
# 0                           Wow... Loved this place.  1
# 1                                 Crust is not good.  0
# 2          Not tasty and the texture was just nasty.  0
# 3  Stopped by during the late May bank holiday of...  1
# 4  The selection on the menu was great and so wer...  1

# %%
columns_name = ['##', '##']
data_yelp.columns = ##

# %%
data_yelp.head()
# Out:
#                                               Review  Sentiment
# 0                           Wow... Loved this place.          1
# 1                                 Crust is not good.          0
# 2          Not tasty and the texture was just nasty.          0
# 3  Stopped by during the late May bank holiday of...          1
# 4  The selection on the menu was great and so wer...          1

# %%
data_yelp.##
# Out:
# (1000, 2)

# %%
data_amazon = pd.read_csv('https://frenzy86.s3.eu-west-2.amazonaws.com/fav/nlp/amazon_cells_labelled.txt', ##, ##)
data_amazon.columns = ##

# %%
data_amazon.##()
# Out:
#                                               Review  Sentiment
# 0  So there is no way for me to plug it in here i...          0
# 1                        Good case, Excellent value.          1
# 2                             Great for the jawbone.          1
# 3  Tied to charger for conversations lasting more...          0
# 4                                  The mic is great.          1

# %%
data_amazon.##
# Out:
# (1000, 2)

# %%
data_imdb = pd.read_csv('https://frenzy86.s3.eu-west-2.amazonaws.com/fav/nlp/imdb_labelled.txt', ##, ##)

# %%
data_imdb.columns = ##

# %%
data_imdb.##
# Out:
# (748, 2)

# %%
data_imdb.##()
# Out:
#                                               Review  Sentiment
# 0  A very, very, very slow-moving, aimless movie ...          0
# 1  Not sure who was more lost - the flat characte...          0
# 2  Attempting artiness with black & white and cle...          0
# 3       Very little music or anything to speak of.            0
# 4  The best scene in the movie was when Gerardo i...          1

# %%
data = data_yelp.append([##,## ], ##)

# %%
data.##
# Out:
# (2748, 2)

# %%
data.##()
# Out:
#                                               Review  Sentiment
# 0                           Wow... Loved this place.          1
# 1                                 Crust is not good.          0
# 2          Not tasty and the texture was just nasty.          0
# 3  Stopped by during the late May bank holiday of...          1
# 4  The selection on the menu was great and so wer...          1

# %%
data['##'].value_counts()
# Out:
# 1    1386
# 0    1362
# Name: Sentiment, dtype: int64

# %%
data.isnull().##()
# Out:
# Review       0
# Sentiment    0
# dtype: int64

# %% [markdown]
# ### Tokenization

# %%
import string

# %%
punct = string.##

# %%
punct
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def text_data_cleaning(sentence):
    doc = nlp(sentence)
    
    tokens = []
    for token in doc:
        if token.lemma_ != "-PRON-":
            temp = token.lemma_.lower().strip()
        else:
            temp = token.lower_
        tokens.append(temp)
    
    cleaned_tokens = []
    for token in tokens:
        if token not in stopwords and token not in punct:
            cleaned_tokens.append(token)
    return cleaned_tokens

# %%
text_data_##("    Hello how are you. Like this video")
# Out:
# ['hello', 'like', 'video']

# %% [markdown]
# ### Vectorization Feature Engineering (TF-IDF)

# %%
from sklearn.svm import ##

# %%
tfidf = TfidfVectorizer(tokenizer = ##)
## = LinearSVC()

# %%
X = data['##']
y = data['##']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 667)

# %%
X_train.shape, X_test.shape
# Out:
# ((2198,), (550,))

# %%
clf = ##([('tfidf', tfidf), ('clf', classifier)])

# %%
clf.##(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('tfidf',
#                  TfidfVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.float64'>,
#                                  encoding='utf-8', input='content',
#                                  lowercase=True, max_df=1.0, max_features=None,
#                                  min_df=1, ngram_range=(1, 1), norm='l2',
#                                  preprocessor=None, smooth_idf=True,
#                                  stop_words=None, strip_accents=None,
#                                  sublinear_tf=False,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function text_data_cleaning at 0x7f6f34f6f620>,
#                                  use_idf=True, vocabulary=None)),
#                 ('clf',
#                  LinearSVC(C=1.0, class_weight=None, dual=True,
#                            fit_intercept=True, intercept_scaling=1,
#                            loss='squared_hinge', max_iter=1000,
#                            multi_class='ovr', penalty='l2', random_state=None,
#                            tol=0.0001, verbose=0))],
#          verbose=False)

# %%
y_pred = clf.##(X_test)

# %%
print(classification_report(y_test, ##))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.81      0.80       285
#            1       0.79      0.75      0.77       265
#
#     accuracy                           0.78       550
#    macro avg       0.78      0.78      0.78       550
# weighted avg       0.78      0.78      0.78       550

# %%
confusion_matrix(y_test, ##)
# Out:
# array([[232,  53],
#        [ 66, 199]])

# %%
clf.##(['Wow, this is amzing lesson'])
# Out:
# array([1])

# %%
clf.##(['Wow, this sucks'])
# Out:
# array([0])

# %%
clf.##(['Worth of watching it. Please like it'])
# Out:
# array([1])

# %%
clf.##(['Loved it. amazing'])
# Out:
# array([1])
