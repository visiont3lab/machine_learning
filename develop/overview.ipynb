# %% [markdown]
# # Machine Learning
# The art of modelling, shaping and analyizing data.

# %% [markdown]
# ## Introduction
#
# 1. Basics of Machine Learning
# 2. Why Machine Learning
# 3. What is Machine Learning
#
# Types of Machine Learning
# 1. Supervised Learning
# 2. Unsupervised Learning
#
# Examples of Real World Applcation

# %% [markdown]
# ## How and where to get Data?
# Out of the box available datasets:
# * dataset 1
# * dataset 2
#
# ### Scraping (Get Data)
# Turn internet into your database
#
# ### Preprocessing
# Pandas and sklearn , (accenni Tableau),preprocessing tools

# %% [markdown]
# ### Supervised Learning
#
# * Linear Regression
#    1. least-squares
#    2. ridge, lasso, and polynomial regression
#
# * Classification
#   1. Logistic Regression
#   2. Isotonic Regression
#   3. K Neirest Neightboorhood (KNN)
#
# * Decision Trees
#
# *  Support Vector Machine  (SVM)
#   1. Linear SVM
#   2. NuSVM (non linear)
#
# * Naive Bayes: Bernoulli - Multinomial
#
# * Ensemble Methods
#   1. Averaging Ensemble Methods: Bagging and Random Forest
#   2. Boosting Ensemble Methods
#
# Important Concepts and Model Evaluation:
#   * feature scaling, cross validation, regularization, confusion matrices, precision-recall and ROC curves, optimizers (SGD, ADAM, ADADELTA) and metrics (MSE, DICE, IOU)

# %% [markdown]
# ### Unsupervised Learning
#
# * Clustering
#   1. Kmeans Clustering
#   3. Density Based Scan Clustering (DBSCAN)
#   4. Gaussian Clustering Model
#
# * Dimensionality Reduction
#   1. Principal Componet Analysis (PCA)
#   2. t-distributed stochastic neighbor embedding (t-SNE)

# %% [markdown]
# ### Real World Applications: Problems and Solutions
# Apply machine learning to real world problem.
#
# 1. Scrap a dataset from the web (ex: Stock Market oscillation), analyze it and test the different studied models.
#
# 2. Develop a simple python web app to solve a chosen machine learning model.

# %% [markdown]
# ## References
# [Machine Learning Full Course | Learn Machine Learning | Machine Learning  | Simplilearn](https://www.youtube.com/watch?v=DWsJc1xnOZo) <br>
# [Intro to Web Scraping with Python and Beautiful Soup](https://www.youtube.com/watch?v=XQgXKtPSzUI&t=535s) <br>
# [Intro to Pandas](https://colab.research.google.com/notebooks/mlcc/intro_to_pandas.ipynb) <br>
# [Machine Learning — Andrew Ng, Stanford University [FULL COURSE]](https://www.youtube.com/watch?v=ng2o98k983k) <br>
# [Practical Machine Learning in Python Full Course](https://www.youtube.com/watch?v=URLwFGwCBb0&t=36663s) <br>
# [StateQuest](https://www.youtube.com/playlist?list=PLLwcx6eVceu47mQ5xy6yqX_2yPasIi_4a) <br>
# [The 5 Clustering Algorithms Data Scientists Need to Know](https://towardsdatascience.com/the-5-clustering-algorithms-data-scientists-need-to-know-a36d136ef68) <br>
# [Unsupervised Machine Learning: Clustering Analysis](https://towardsdatascience.com/unsupervised-machine-learning-clustering-analysis-d40f2b34ae7e) <br>
# [Kaggle Intro to Machine Learning](https://www.kaggle.com/learn/intro-to-machine-learning) <br>
# [Machine Learning Google Colab Crash Course](https://developers.google.com/machine-learning/crash-course) <br>
# [Machine Learning Course Github](https://github.com/machinelearningmindset/machine-learning-course) <br>
# [Machine Learning Sklearn Udemy](https://www.udemy.com/course/machine-learning-with-scikit-learn/) <br>
# [scikit-learn Tutorials](https://scikit-learn.org/stable/tutorial/index.html) <br>
# [Iniziare Con Sklearn](https://riptutorial.com/it/scikit-learn)  <br>
# [Scikit-learn Tutorial: Machine Learning in Python](https://www.dataquest.io/blog/sci-kit-learn-tutorial/) <br>
# [Applied Machine Learning in Python Coursera ](https://www.coursera.org/learn/python-machine-learning) <br>
# [Sklearn User Guide](https://scikit-learn.org/stable/user_guide.html) <br>
# [Scikit-Learn Tutorial | Machine Learning With Scikit-Learn | Sklearn | Python Tutorial | Simplilearn](https://www.youtube.com/watch?v=0Lt9w-BxKFQ) <br>
# [Main Sklearn Guide Reference](https://scikit-learn.org/stable/)
